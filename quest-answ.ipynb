# %%
import pandas as pd
df=pd.read_csv('/content/100_Unique_QA_Dataset.csv')

# %%
df.head()
# Out:
#                                           question      answer
# 0                   What is the capital of France?       Paris
# 1                  What is the capital of Germany?      Berlin
# 2               Who wrote 'To Kill a Mockingbird'?  Harper-Lee
# 3  What is the largest planet in our solar system?     Jupiter
# 4   What is the boiling point of water in Celsius?         100

# %%
#tokenize
def tokenize(text):
  text=text.lower()
  text.replace('?','')
  text=text.replace("'","")
  return text.split()

# %%
tokenize('What is the capital of Germany?')
# Out:
# ['what', 'is', 'the', 'capital', 'of', 'germany?']

# %%
#vocab
vocab={'<UNK>':0}

# %%
def build_vocab(row):
  tokenized_question=tokenize(row['question'])
  tokenized_answer=tokenize(row['answer'])
  merged_tokens=tokenized_question+tokenized_answer
  for token in merged_tokens:

    if token not in vocab:
      vocab[token]=len(vocab)

# %%
df.apply(build_vocab,axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 85    None
# 86    None
# 87    None
# 88    None
# 89    None
# Length: 90, dtype: object

# %%
len(vocab)
# Out:
# 336

# %%
#convert words to  numerical indices
def text_to_indices(text,vocab):
  indexed_text=[]
  for token in tokenize(text):
    if token in vocab:
      indexed_text.append(vocab[token])
    else:
        indexed_text.append(vocab['<UNK>'])
  return indexed_text

# %%
text_to_indices("what is campusx",vocab)
# Out:
# [1, 2, 0]

# %%
import torch
from torch.utils.data import Dataset,DataLoader

# %%
class QADataset(Dataset):
  def __init__(self,df,vocab):
    self.df=df
    self.vocab=vocab
  def __len__(self):
    return self.df.shape[0]

  def __getitem__(self,index):
    numerical_question=text_to_indices(self.df.iloc[index]['question'],self.vocab)
    numerical_answer=text_to_indices(self.df.iloc[index]['answer'],self.vocab)
    return torch.tensor(numerical_question),torch.tensor(numerical_answer)

# %%
dataset=QADataset(df,vocab)

# %%
dataloader=DataLoader(dataset,batch_size=1,shuffle=True)

# %%
for question,answer in dataloader:
  print(question,answer[0])
# Out:
# tensor([[ 10, 146,   3, 147, 177,   5,   3,  72, 178]]) tensor([179])
# tensor([[ 42, 206,   2,  14, 207, 208, 209, 210]]) tensor([211])
# tensor([[ 42, 120, 121,   3, 122, 123, 124]]) tensor([125])
# tensor([[ 42,   2,   3, 216, 142, 174, 217, 175]]) tensor([218])
# tensor([[ 42,  18, 121,   3, 192, 193]]) tensor([194])
# tensor([[ 10,  77,   3, 307,  19, 308]]) tensor([309])
# tensor([[42, 18,  2, 63, 64,  3, 65, 66]]) tensor([67])
# tensor([[ 42, 273, 274,  14, 275, 276, 164, 277]]) tensor([278])
# tensor([[  1,   2,   3,   4,   5, 246, 247]]) tensor([248])
# tensor([[ 42, 265,   2, 266,  85, 267, 268]]) tensor([269])
# tensor([[ 1,  2,  3, 71,  5, 54]]) tensor([270])
# tensor([[  1,   2,   3, 147, 120,  85,   3, 288, 289]]) tensor([125])
# tensor([[ 42, 310, 311, 121,  14, 312, 313, 164, 314, 315, 316, 317]]) tensor([318])
# tensor([[ 10,  11, 163, 164, 165]]) tensor([166])
# tensor([[ 42, 142,   2, 234,  12,   3, 235, 236]]) tensor([237])
# tensor([[ 42, 142,   2,  63,  39,   3, 333, 334]]) tensor([335])
# tensor([[  1,   2,   3,   4,   5, 212]]) tensor([213])
# tensor([[  1,   2,   3, 219,   5,  14, 220, 221]]) tensor([222])
# tensor([[ 42, 142, 121,   3, 257,   5, 258]]) tensor([259])
# tensor([[ 80,  81, 133,  83,  19,   3,  21,  22]]) tensor([36])
# tensor([[ 1,  2,  3,  4,  5, 54]]) tensor([55])
# tensor([[ 1,  2,  3,  4,  5, 75]]) tensor([76])
# tensor([[ 42, 142,   2, 143,  39, 144]]) tensor([145])
# tensor([[ 1,  2,  3, 37, 38, 39, 40]]) tensor([41])
# tensor([[ 42,  18,   2,   3, 292,  12,   3, 293]]) tensor([211])
# tensor([[ 10, 319,   3, 320, 321]]) tensor([322])
# tensor([[  1,   2,   3, 229,   5, 230, 231, 232]]) tensor([233])
# tensor([[  1,  89, 238, 239, 240, 241]]) tensor([242])
# tensor([[10, 29,  3, 30, 31]]) tensor([32])
# tensor([[ 10, 146,   3, 147, 281,  95, 282,   5,   3, 283]]) tensor([284])
# tensor([[ 42,  88,  89, 251, 252,  19,  39, 253]]) tensor([254])
# tensor([[  1,   2,   3, 152,  88,  19, 198, 199]]) tensor([200])
# tensor([[ 10,  11, 195, 164, 196]]) tensor([197])
# tensor([[ 1,  2,  3, 71,  5,  3, 72, 73]]) tensor([74])
# tensor([[ 42, 223, 121, 224, 225,  19,  14, 226, 227]]) tensor([228])
# tensor([[  1,   2,   3,  37,  38,  39, 167]]) tensor([168])
# tensor([[ 1,  2,  3, 17, 18, 19, 20, 21, 22]]) tensor([23])
# tensor([[ 80,  81, 271, 157,  14, 272, 159]]) tensor([36])
# tensor([[ 10,   2,  63,  64,   3, 294,   5, 295]]) tensor([296])
# tensor([[ 42, 260, 261, 121, 262, 263]]) tensor([264])
# tensor([[ 1,  2,  3, 33, 34,  5, 35]]) tensor([36])
# tensor([[  1,   2,   3,  33,  34,   5, 255]]) tensor([256])
# tensor([[ 42, 173,   2,   3,  17, 174, 175]]) tensor([176])
# tensor([[ 10,  77, 214]]) tensor([215])
# tensor([[  1,   2,   3,   4,   5, 290]]) tensor([291])
# tensor([[ 42, 103,   2,   3, 104]]) tensor([105])
# tensor([[ 10, 146,   3, 147, 148,  12, 149,  85,   3, 150]]) tensor([151])
# tensor([[ 42,   2,   3, 285, 217, 286]]) tensor([287])
# tensor([[42, 43, 44, 45, 46, 47, 48]]) tensor([49])
# tensor([[ 80,  81, 201,  83,  19,   3, 202, 203, 204]]) tensor([205])
# tensor([[1, 2, 3, 4, 5, 6]]) tensor([7])
# tensor([[  1,   2,   3, 106,   5, 107,  19, 108]]) tensor([109])
# tensor([[  1,   2,   3,   4,   5, 112]]) tensor([328])
# tensor([[ 42, 323,   2, 324,  63,  64,   3, 325, 326]]) tensor([327])
# tensor([[ 1,  2,  3, 94, 95, 96]]) tensor([97])
# tensor([[ 42, 110,   2, 111,  19, 112]]) tensor([113])
# tensor([[ 42, 180,   2,  63,  39, 181, 182,  12, 183, 184]]) tensor([185])
# tensor([[  1,   2,   3,  71,   5, 161]]) tensor([162])
# tensor([[10,  2,  3, 68,  5, 69]]) tensor([70])
# tensor([[  1,   2,   3,   4,   5, 140]]) tensor([141])
# tensor([[  1,   2,   3, 186, 187, 188, 189]]) tensor([190])
# tensor([[  1,   2,   3,   4,   5, 116]]) tensor([117])
# tensor([[10, 11, 12, 13, 14, 15]]) tensor([16])
# tensor([[1, 2, 3, 4, 5, 8]]) tensor([9])
# tensor([[ 1,  2,  3, 50, 51, 19,  3, 52]]) tensor([53])
# tensor([[ 42, 142,   2, 143,  39, 181, 279]]) tensor([280])
# tensor([[ 42, 129,   2,  63,  64,   3, 130, 131]]) tensor([132])
# tensor([[  1,   2,   3, 169, 170, 171,  85,  86]]) tensor([172])
# tensor([[  1,   2,   3,  17, 118,  85,  86]]) tensor([119])
# tensor([[  1,   2,   3, 243,   5, 244]]) tensor([245])
# tensor([[ 42, 329,   2,  63,  64,   3, 330,   5, 331]]) tensor([332])
# tensor([[ 10,  98,   3, 107, 249]]) tensor([250])
# tensor([[ 80,  81, 156, 157,  14, 158, 159]]) tensor([160])
# tensor([[  1,   2,   3, 152, 153,  19, 154]]) tensor([155])
# tensor([[10, 98,  3, 99]]) tensor([100])
# tensor([[ 10,  77, 114]]) tensor([115])
# tensor([[  1,   2,   3,   4,   5, 101]]) tensor([102])
# tensor([[42, 88, 89, 90, 91, 39, 92]]) tensor([93])
# tensor([[  1,   2,   3,  94, 142,  19,   3,  52]]) tensor([191])
# tensor([[ 1,  2,  3, 60, 25,  5, 26, 19, 61]]) tensor([62])
# tensor([[ 80,  81, 299,  83,  19,  14, 300]]) tensor([87])
# tensor([[  1,   2,   3,  37, 137,   5, 138]]) tensor([139])
# tensor([[10, 56,  3, 57,  5, 58]]) tensor([59])
# tensor([[  1,   2,   3,   4,   5, 297]]) tensor([298])
# tensor([[ 42, 301, 302, 121, 303, 164, 304, 305]]) tensor([306])
# tensor([[10, 77, 78]]) tensor([79])
# tensor([[ 1,  2,  3, 24, 25,  5, 26, 19, 27]]) tensor([28])
# tensor([[80, 81, 82, 83, 84, 85, 86]]) tensor([87])
# tensor([[ 10,  29, 134, 135]]) tensor([136])
# tensor([[  1,   2,   3, 126, 127,  19,   3,  52]]) tensor([128])

# %%
  import torch.nn as nn

# %%
class SimpleRNN(nn.Module):

  def __init__(self,vocab_size):
    super().__init__()
    self.embedding=nn.Embedding(vocab_size,embedding_dim=50)
    self.rnn=nn.RNN(50,64,batch_first=True)
    self.fc=nn.Linear(64,vocab_size)
  def forward(self,question):
    embedded_question=self.embedding(question)
    hidden,final=self.rnn(embedded_question)
    output=self.fc(final.squeeze(0))
    return output

# %%
x=nn.Embedding(324,embedding_dim=50)
y=nn.RNN(50,64,batch_first=True)
z=nn.Linear(64,324)

a=dataset[0][0].reshape(1,6)
print("Shape of a:",a.shape)

b=x(a)
print("Shape of b:",b.shape)

c,d=y(b)
print("Shape of c:",c.shape)
print("Shape of d",d.shape)

e=z(d.squeeze(0))
print("Shape of e:",e.shape)
# Out:
# Shape of a: torch.Size([1, 6])
# Shape of b: torch.Size([1, 6, 50])
# Shape of c: torch.Size([1, 6, 64])
# Shape of d torch.Size([1, 1, 64])
# Shape of e: torch.Size([1, 324])

# %%
learning_rate=0.001
epochs=20

# %%
model=SimpleRNN(len(vocab))
criterion=nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters(),lr=learning_rate)

# %%
#training loop
for epoch in range(epochs):
  total_loss=0
  for question,answer in dataloader:
    optimizer.zero_grad()

    #forward pass
    output=model(question)

    #loss->output shape(1,324)
    loss=criterion(output,answer[0])

    #gradients
    loss.backward()
    #update
    optimizer.step()

    total_loss=total_loss+loss.item()
    print(f"Epoch{epoch+1},Loss:{total_loss:4f}")
# Out:
# Epoch1,Loss:5.872055
# Epoch1,Loss:11.932389
# Epoch1,Loss:17.945444
# Epoch1,Loss:23.948284
# Epoch1,Loss:29.701139
# Epoch1,Loss:35.665572
# Epoch1,Loss:41.162794
# Epoch1,Loss:46.693023
# Epoch1,Loss:51.914065
# Epoch1,Loss:57.707977
# Epoch1,Loss:63.251677
# Epoch1,Loss:68.819987
# Epoch1,Loss:74.676688
# Epoch1,Loss:79.898100
# Epoch1,Loss:85.497821
# Epoch1,Loss:91.487199
# Epoch1,Loss:97.238551
# Epoch1,Loss:103.109483
# Epoch1,Loss:108.700855
# Epoch1,Loss:114.370463
# Epoch1,Loss:120.204878
# Epoch1,Loss:126.170300
# Epoch1,Loss:132.228161
# Epoch1,Loss:138.138210
# Epoch1,Loss:143.817849
# Epoch1,Loss:150.220146
# Epoch1,Loss:156.161940
# Epoch1,Loss:162.063722
# Epoch1,Loss:167.952170
# Epoch1,Loss:173.902268
# Epoch1,Loss:180.464134
# Epoch1,Loss:186.568309
# Epoch1,Loss:191.815709
# Epoch1,Loss:197.490710
# Epoch1,Loss:203.506672
# Epoch1,Loss:209.089813
# Epoch1,Loss:214.941636
# Epoch1,Loss:220.851202
# Epoch1,Loss:226.319348
# Epoch1,Loss:232.530189
# Epoch1,Loss:237.918977
# Epoch1,Loss:243.664187
# Epoch1,Loss:249.912785
# Epoch1,Loss:256.070394
# Epoch1,Loss:261.988358
# Epoch1,Loss:268.131866
# Epoch1,Loss:274.305809
# Epoch1,Loss:279.794180
# Epoch1,Loss:285.881993
# Epoch1,Loss:291.596593
# Epoch1,Loss:297.350499
# Epoch1,Loss:303.458845
# Epoch1,Loss:309.171577
# Epoch1,Loss:314.822406
# Epoch1,Loss:320.436604
# Epoch1,Loss:326.482973
# Epoch1,Loss:331.901315
# Epoch1,Loss:337.788238
# Epoch1,Loss:343.195613
# Epoch1,Loss:348.750021
# Epoch1,Loss:354.603770
# Epoch1,Loss:361.052477
# Epoch1,Loss:366.537340
# Epoch1,Loss:372.448372
# Epoch1,Loss:378.392505
# Epoch1,Loss:383.802794
# Epoch1,Loss:389.553716
# Epoch1,Loss:395.339796
# Epoch1,Loss:401.407751
# Epoch1,Loss:407.687491
# Epoch1,Loss:413.416353
# Epoch1,Loss:419.275534
# Epoch1,Loss:425.044911
# Epoch1,Loss:431.083684
# Epoch1,Loss:436.792509
# Epoch1,Loss:442.763764
# Epoch1,Loss:448.586873
# Epoch1,Loss:454.925017
# Epoch1,Loss:460.794574
# Epoch1,Loss:466.778862
# Epoch1,Loss:472.437826
# Epoch1,Loss:477.688450
# Epoch1,Loss:483.639726
# Epoch1,Loss:489.140164
# Epoch1,Loss:495.057875
# Epoch1,Loss:500.490718
# Epoch1,Loss:506.045058
# Epoch1,Loss:511.447289
# Epoch1,Loss:517.691308
# Epoch1,Loss:523.606246
# Epoch2,Loss:5.389122
# Epoch2,Loss:10.590176
# Epoch2,Loss:15.688670
# Epoch2,Loss:21.013436
# Epoch2,Loss:26.495777
# Epoch2,Loss:31.629747
# Epoch2,Loss:36.599345
# Epoch2,Loss:41.526739
# Epoch2,Loss:46.694194
# Epoch2,Loss:52.434491
# Epoch2,Loss:57.723680
# Epoch2,Loss:62.839490
# Epoch2,Loss:67.935240
# Epoch2,Loss:72.986163
# Epoch2,Loss:78.084996
# Epoch2,Loss:82.942891
# Epoch2,Loss:88.165844
# Epoch2,Loss:93.212198
# Epoch2,Loss:98.309553
# Epoch2,Loss:103.593503
# Epoch2,Loss:108.500790
# Epoch2,Loss:113.672966
# Epoch2,Loss:119.021879
# Epoch2,Loss:123.549172
# Epoch2,Loss:129.141642
# Epoch2,Loss:134.612099
# Epoch2,Loss:139.595830
# Epoch2,Loss:144.268967
# Epoch2,Loss:149.506068
# Epoch2,Loss:155.205137
# Epoch2,Loss:160.614328
# Epoch2,Loss:166.260041
# Epoch2,Loss:171.002747
# Epoch2,Loss:176.299272
# Epoch2,Loss:181.320385
# Epoch2,Loss:186.614918
# Epoch2,Loss:191.813006
# Epoch2,Loss:197.036418
# Epoch2,Loss:201.609401
# Epoch2,Loss:206.358914
# Epoch2,Loss:211.394216
# Epoch2,Loss:216.231962
# Epoch2,Loss:222.051417
# Epoch2,Loss:227.263895
# Epoch2,Loss:232.489403
# Epoch2,Loss:237.473140
# Epoch2,Loss:242.553002
# Epoch2,Loss:247.601768
# Epoch2,Loss:252.419945
# Epoch2,Loss:256.738860
# Epoch2,Loss:261.990617
# Epoch2,Loss:266.797822
# Epoch2,Loss:272.108877
# Epoch2,Loss:277.031171
# Epoch2,Loss:282.472294
# Epoch2,Loss:287.340083
# Epoch2,Loss:292.620409
# Epoch2,Loss:297.241148
# Epoch2,Loss:302.794343
# Epoch2,Loss:307.962979
# Epoch2,Loss:312.181787
# Epoch2,Loss:317.332367
# Epoch2,Loss:322.151483
# Epoch2,Loss:327.202936
# Epoch2,Loss:331.961545
# Epoch2,Loss:336.997544
# Epoch2,Loss:342.304494
# Epoch2,Loss:346.915287
# Epoch2,Loss:351.358577
# Epoch2,Loss:356.315892
# Epoch2,Loss:361.422794
# Epoch2,Loss:366.448220
# Epoch2,Loss:371.477406
# Epoch2,Loss:376.017645
# Epoch2,Loss:381.007431
# Epoch2,Loss:386.172484
# Epoch2,Loss:391.311768
# Epoch2,Loss:396.220787
# Epoch2,Loss:401.075211
# Epoch2,Loss:406.578866
# Epoch2,Loss:411.187285
# Epoch2,Loss:416.045799
# Epoch2,Loss:421.428776
# Epoch2,Loss:426.648424
# Epoch2,Loss:431.249964
# Epoch2,Loss:435.833269
# Epoch2,Loss:440.790335
# Epoch2,Loss:444.841287
# Epoch2,Loss:450.018335
# Epoch2,Loss:455.501042
# Epoch3,Loss:3.699217
# Epoch3,Loss:7.497032
# Epoch3,Loss:11.930441
# Epoch3,Loss:15.992774
# Epoch3,Loss:20.637897
# Epoch3,Loss:25.029166
# Epoch3,Loss:29.182845
# Epoch3,Loss:34.231280
# Epoch3,Loss:38.547809
# Epoch3,Loss:42.520681
# Epoch3,Loss:46.765240
# Epoch3,Loss:51.304258
# Epoch3,Loss:55.521835
# Epoch3,Loss:60.154443
# Epoch3,Loss:64.668561
# Epoch3,Loss:68.736670
# Epoch3,Loss:73.211475
# Epoch3,Loss:77.634888
# Epoch3,Loss:81.646284
# Epoch3,Loss:85.926197
# Epoch3,Loss:90.115057
# Epoch3,Loss:93.973649
# Epoch3,Loss:98.210651
# Epoch3,Loss:102.755956
# Epoch3,Loss:107.038778
# Epoch3,Loss:111.804475
# Epoch3,Loss:116.452275
# Epoch3,Loss:120.776260
# Epoch3,Loss:124.245357
# Epoch3,Loss:127.448814
# Epoch3,Loss:131.756571
# Epoch3,Loss:135.773161
# Epoch3,Loss:139.927193
# Epoch3,Loss:143.923563
# Epoch3,Loss:147.741781
# Epoch3,Loss:152.139096
# Epoch3,Loss:155.851184
# Epoch3,Loss:159.558511
# Epoch3,Loss:163.993739
# Epoch3,Loss:168.280971
# Epoch3,Loss:172.015999
# Epoch3,Loss:175.673320
# Epoch3,Loss:179.479144
# Epoch3,Loss:183.860874
# Epoch3,Loss:187.866245
# Epoch3,Loss:191.057081
# Epoch3,Loss:195.178356
# Epoch3,Loss:199.313691
# Epoch3,Loss:203.655859
# Epoch3,Loss:207.618111
# Epoch3,Loss:212.287668
# Epoch3,Loss:216.178355
# Epoch3,Loss:220.265109
# Epoch3,Loss:224.230258
# Epoch3,Loss:227.844399
# Epoch3,Loss:231.816638
# Epoch3,Loss:235.909249
# Epoch3,Loss:239.925540
# Epoch3,Loss:243.737014
# Epoch3,Loss:248.001214
# Epoch3,Loss:251.879132
# Epoch3,Loss:255.645598
# Epoch3,Loss:259.546253
# Epoch3,Loss:263.781544
# Epoch3,Loss:267.904592
# Epoch3,Loss:272.143456
# Epoch3,Loss:276.361604
# Epoch3,Loss:281.114847
# Epoch3,Loss:286.172812
# Epoch3,Loss:291.114907
# Epoch3,Loss:295.218002
# Epoch3,Loss:299.470640
# Epoch3,Loss:303.877095
# Epoch3,Loss:308.569469
# Epoch3,Loss:313.413636
# Epoch3,Loss:317.931837
# Epoch3,Loss:321.279609
# Epoch3,Loss:325.409763
# Epoch3,Loss:329.604221
# Epoch3,Loss:333.955209
# Epoch3,Loss:338.223184
# Epoch3,Loss:342.550248
# Epoch3,Loss:346.184222
# Epoch3,Loss:350.794213
# Epoch3,Loss:355.185147
# Epoch3,Loss:359.215043
# Epoch3,Loss:363.370147
# Epoch3,Loss:367.355742
# Epoch3,Loss:371.747262
# Epoch3,Loss:376.294593
# Epoch4,Loss:3.178525
# Epoch4,Loss:6.945747
# Epoch4,Loss:10.741720
# Epoch4,Loss:14.351969
# Epoch4,Loss:18.343444
# Epoch4,Loss:22.047609
# Epoch4,Loss:25.324593
# Epoch4,Loss:29.280774
# Epoch4,Loss:32.895126
# Epoch4,Loss:36.176864
# Epoch4,Loss:39.910703
# Epoch4,Loss:43.477302
# Epoch4,Loss:47.071246
# Epoch4,Loss:50.443756
# Epoch4,Loss:54.106523
# Epoch4,Loss:58.424114
# Epoch4,Loss:61.831569
# Epoch4,Loss:65.588717
# Epoch4,Loss:69.791337
# Epoch4,Loss:73.808058
# Epoch4,Loss:76.358373
# Epoch4,Loss:79.959389
# Epoch4,Loss:83.668493
# Epoch4,Loss:87.029799
# Epoch4,Loss:89.985314
# Epoch4,Loss:92.984900
# Epoch4,Loss:96.388195
# Epoch4,Loss:99.477163
# Epoch4,Loss:103.337555
# Epoch4,Loss:106.701707
# Epoch4,Loss:110.854362
# Epoch4,Loss:114.461798
# Epoch4,Loss:117.930514
# Epoch4,Loss:121.157146
# Epoch4,Loss:124.578985
# Epoch4,Loss:128.272188
# Epoch4,Loss:131.659323
# Epoch4,Loss:134.894241
# Epoch4,Loss:138.630774
# Epoch4,Loss:142.326586
# Epoch4,Loss:145.744977
# Epoch4,Loss:149.056824
# Epoch4,Loss:152.614322
# Epoch4,Loss:156.261807
# Epoch4,Loss:159.329697
# Epoch4,Loss:162.581778
# Epoch4,Loss:165.472221
# Epoch4,Loss:168.526855
# Epoch4,Loss:172.000602
# Epoch4,Loss:174.599218
# Epoch4,Loss:177.210812
# Epoch4,Loss:179.846573
# Epoch4,Loss:182.891824
# Epoch4,Loss:186.817143
# Epoch4,Loss:190.524291
# Epoch4,Loss:194.090468
# Epoch4,Loss:197.071616
# Epoch4,Loss:200.546527
# Epoch4,Loss:204.492455
# Epoch4,Loss:207.977890
# Epoch4,Loss:211.595761
# Epoch4,Loss:215.504159
# Epoch4,Loss:219.427065
# Epoch4,Loss:222.795923
# Epoch4,Loss:225.722223
# Epoch4,Loss:229.112713
# Epoch4,Loss:232.774268
# Epoch4,Loss:235.878865
# Epoch4,Loss:239.578200
# Epoch4,Loss:242.859643
# Epoch4,Loss:246.303884
# Epoch4,Loss:249.389997
# Epoch4,Loss:252.909795
# Epoch4,Loss:256.477536
# Epoch4,Loss:259.651181
# Epoch4,Loss:263.224400
# Epoch4,Loss:266.352480
# Epoch4,Loss:270.416659
# Epoch4,Loss:273.517856
# Epoch4,Loss:277.358169
# Epoch4,Loss:281.026740
# Epoch4,Loss:284.613023
# Epoch4,Loss:287.632055
# Epoch4,Loss:291.558833
# Epoch4,Loss:295.011672
# Epoch4,Loss:298.346839
# Epoch4,Loss:301.768529
# Epoch4,Loss:304.997480
# Epoch4,Loss:308.495420
# Epoch4,Loss:312.603795
# Epoch5,Loss:2.791281
# Epoch5,Loss:5.625190
# Epoch5,Loss:8.283756
# Epoch5,Loss:10.332105
# Epoch5,Loss:13.475483
# Epoch5,Loss:16.506573
# Epoch5,Loss:19.031816
# Epoch5,Loss:21.552790
# Epoch5,Loss:24.994871
# Epoch5,Loss:27.814957
# Epoch5,Loss:30.539462
# Epoch5,Loss:33.663004
# Epoch5,Loss:36.529270
# Epoch5,Loss:38.759538
# Epoch5,Loss:41.690768
# Epoch5,Loss:44.797186
# Epoch5,Loss:47.503458
# Epoch5,Loss:50.580273
# Epoch5,Loss:53.945041
# Epoch5,Loss:57.184851
# Epoch5,Loss:59.826481
# Epoch5,Loss:62.470689
# Epoch5,Loss:65.255600
# Epoch5,Loss:68.314443
# Epoch5,Loss:71.328694
# Epoch5,Loss:74.461094
# Epoch5,Loss:77.286826
# Epoch5,Loss:80.545344
# Epoch5,Loss:83.678623
# Epoch5,Loss:85.967129
# Epoch5,Loss:89.145528
# Epoch5,Loss:92.597750
# Epoch5,Loss:95.189637
# Epoch5,Loss:97.325126
# Epoch5,Loss:100.013980
# Epoch5,Loss:103.191242
# Epoch5,Loss:106.185106
# Epoch5,Loss:109.801565
# Epoch5,Loss:112.659465
# Epoch5,Loss:115.624561
# Epoch5,Loss:118.490085
# Epoch5,Loss:121.853646
# Epoch5,Loss:124.918641
# Epoch5,Loss:128.010351
# Epoch5,Loss:130.607724
# Epoch5,Loss:133.766935
# Epoch5,Loss:136.458814
# Epoch5,Loss:139.991877
# Epoch5,Loss:142.858356
# Epoch5,Loss:145.465679
# Epoch5,Loss:148.808721
# Epoch5,Loss:151.732342
# Epoch5,Loss:153.771449
# Epoch5,Loss:156.470893
# Epoch5,Loss:159.311583
# Epoch5,Loss:162.647096
# Epoch5,Loss:165.425419
# Epoch5,Loss:168.654653
# Epoch5,Loss:171.678023
# Epoch5,Loss:174.688651
# Epoch5,Loss:177.755182
# Epoch5,Loss:180.187500
# Epoch5,Loss:183.636406
# Epoch5,Loss:186.979383
# Epoch5,Loss:189.566301
# Epoch5,Loss:192.728934
# Epoch5,Loss:195.305971
# Epoch5,Loss:197.837421
# Epoch5,Loss:200.405190
# Epoch5,Loss:203.181915
# Epoch5,Loss:205.597733
# Epoch5,Loss:208.401496
# Epoch5,Loss:211.478314
# Epoch5,Loss:214.251567
# Epoch5,Loss:216.320967
# Epoch5,Loss:220.099536
# Epoch5,Loss:222.401746
# Epoch5,Loss:225.698492
# Epoch5,Loss:228.290896
# Epoch5,Loss:230.595582
# Epoch5,Loss:233.682087
# Epoch5,Loss:236.786140
# Epoch5,Loss:239.165529
# Epoch5,Loss:241.741417
# Epoch5,Loss:244.661858
# Epoch5,Loss:247.598478
# Epoch5,Loss:250.440484
# Epoch5,Loss:253.168382
# Epoch5,Loss:256.881213
# Epoch5,Loss:259.978295
# Epoch6,Loss:2.661688
# Epoch6,Loss:4.844702
# Epoch6,Loss:7.086120
# Epoch6,Loss:9.700418
# Epoch6,Loss:11.708109
# Epoch6,Loss:14.083815
# Epoch6,Loss:15.974303
# Epoch6,Loss:18.139763
# Epoch6,Loss:19.676427
# Epoch6,Loss:22.334761
# Epoch6,Loss:24.694816
# Epoch6,Loss:27.138143
# Epoch6,Loss:29.374412
# Epoch6,Loss:31.328729
# Epoch6,Loss:34.109266
# Epoch6,Loss:37.284833
# Epoch6,Loss:39.249631
# Epoch6,Loss:41.222551
# Epoch6,Loss:43.350038
# Epoch6,Loss:45.411723
# Epoch6,Loss:47.074721
# Epoch6,Loss:49.551510
# Epoch6,Loss:51.240846
# Epoch6,Loss:52.963660
# Epoch6,Loss:55.034282
# Epoch6,Loss:56.738792
# Epoch6,Loss:59.072555
# Epoch6,Loss:61.410866
# Epoch6,Loss:63.745900
# Epoch6,Loss:66.003206
# Epoch6,Loss:68.255468
# Epoch6,Loss:70.417008
# Epoch6,Loss:72.463018
# Epoch6,Loss:75.165847
# Epoch6,Loss:77.355437
# Epoch6,Loss:79.729766
# Epoch6,Loss:81.974682
# Epoch6,Loss:84.221055
# Epoch6,Loss:87.114075
# Epoch6,Loss:89.647856
# Epoch6,Loss:92.442405
# Epoch6,Loss:95.206681
# Epoch6,Loss:97.714153
# Epoch6,Loss:100.267905
# Epoch6,Loss:102.272075
# Epoch6,Loss:104.855539
# Epoch6,Loss:107.510915
# Epoch6,Loss:109.869894
# Epoch6,Loss:112.574319
# Epoch6,Loss:114.278360
# Epoch6,Loss:116.396381
# Epoch6,Loss:119.482182
# Epoch6,Loss:121.996846
# Epoch6,Loss:124.912488
# Epoch6,Loss:127.680510
# Epoch6,Loss:130.228975
# Epoch6,Loss:132.646946
# Epoch6,Loss:134.140471
# Epoch6,Loss:136.326912
# Epoch6,Loss:139.133219
# Epoch6,Loss:141.852732
# Epoch6,Loss:143.586632
# Epoch6,Loss:146.316052
# Epoch6,Loss:147.713105
# Epoch6,Loss:149.750383
# Epoch6,Loss:152.281595
# Epoch6,Loss:154.360485
# Epoch6,Loss:156.633035
# Epoch6,Loss:159.326384
# Epoch6,Loss:161.732287
# Epoch6,Loss:164.758579
# Epoch6,Loss:167.285093
# Epoch6,Loss:170.344218
# Epoch6,Loss:172.872914
# Epoch6,Loss:175.153896
# Epoch6,Loss:177.737243
# Epoch6,Loss:179.947024
# Epoch6,Loss:182.523626
# Epoch6,Loss:185.090819
# Epoch6,Loss:188.047237
# Epoch6,Loss:190.161242
# Epoch6,Loss:192.815284
# Epoch6,Loss:195.915369
# Epoch6,Loss:198.367182
# Epoch6,Loss:200.686543
# Epoch6,Loss:202.907087
# Epoch6,Loss:204.775111
# Epoch6,Loss:206.690322
# Epoch6,Loss:209.095017
# Epoch6,Loss:211.802166
# Epoch7,Loss:1.125697
# Epoch7,Loss:2.643128
# Epoch7,Loss:5.083983
# Epoch7,Loss:6.761245
# Epoch7,Loss:7.768957
# Epoch7,Loss:9.799009
# Epoch7,Loss:11.654455
# Epoch7,Loss:13.658486
# Epoch7,Loss:15.484868
# Epoch7,Loss:17.367593
# Epoch7,Loss:18.933310
# Epoch7,Loss:20.979278
# Epoch7,Loss:23.344491
# Epoch7,Loss:24.301351
# Epoch7,Loss:26.129825
# Epoch7,Loss:27.689500
# Epoch7,Loss:29.540160
# Epoch7,Loss:31.239475
# Epoch7,Loss:33.400878
# Epoch7,Loss:35.530338
# Epoch7,Loss:37.543873
# Epoch7,Loss:39.039172
# Epoch7,Loss:40.677063
# Epoch7,Loss:42.201209
# Epoch7,Loss:43.902955
# Epoch7,Loss:45.718399
# Epoch7,Loss:47.239771
# Epoch7,Loss:48.828031
# Epoch7,Loss:50.581200
# Epoch7,Loss:52.770620
# Epoch7,Loss:55.007843
# Epoch7,Loss:57.258431
# Epoch7,Loss:59.752736
# Epoch7,Loss:61.679359
# Epoch7,Loss:64.120777
# Epoch7,Loss:66.021956
# Epoch7,Loss:68.008550
# Epoch7,Loss:69.536569
# Epoch7,Loss:71.184377
# Epoch7,Loss:72.983322
# Epoch7,Loss:75.066563
# Epoch7,Loss:77.136198
# Epoch7,Loss:78.661130
# Epoch7,Loss:80.258844
# Epoch7,Loss:81.568616
# Epoch7,Loss:83.319413
# Epoch7,Loss:85.504818
# Epoch7,Loss:87.353570
# Epoch7,Loss:88.969815
# Epoch7,Loss:90.249092
# Epoch7,Loss:91.626898
# Epoch7,Loss:93.680636
# Epoch7,Loss:95.368224
# Epoch7,Loss:97.089719
# Epoch7,Loss:99.199991
# Epoch7,Loss:101.593765
# Epoch7,Loss:102.664308
# Epoch7,Loss:105.036064
# Epoch7,Loss:107.339579
# Epoch7,Loss:109.266582
# Epoch7,Loss:111.794903
# Epoch7,Loss:113.820953
# Epoch7,Loss:115.400286
# Epoch7,Loss:117.608277
# Epoch7,Loss:120.172984
# Epoch7,Loss:121.672597
# Epoch7,Loss:123.253645
# Epoch7,Loss:124.778227
# Epoch7,Loss:127.059063
# Epoch7,Loss:129.851317
# Epoch7,Loss:131.161960
# Epoch7,Loss:133.113163
# Epoch7,Loss:134.970343
# Epoch7,Loss:136.972090
# Epoch7,Loss:139.276202
# Epoch7,Loss:140.567411
# Epoch7,Loss:142.548378
# Epoch7,Loss:144.009400
# Epoch7,Loss:145.554941
# Epoch7,Loss:148.142564
# Epoch7,Loss:150.085380
# Epoch7,Loss:152.153768
# Epoch7,Loss:154.767318
# Epoch7,Loss:156.187684
# Epoch7,Loss:157.931524
# Epoch7,Loss:159.718851
# Epoch7,Loss:161.364488
# Epoch7,Loss:163.578143
# Epoch7,Loss:165.245927
# Epoch7,Loss:167.370754
# Epoch8,Loss:1.203527
# Epoch8,Loss:2.921431
# Epoch8,Loss:4.801587
# Epoch8,Loss:6.494400
# Epoch8,Loss:8.197539
# Epoch8,Loss:8.830661
# Epoch8,Loss:10.908011
# Epoch8,Loss:11.744806
# Epoch8,Loss:12.848926
# Epoch8,Loss:14.170500
# Epoch8,Loss:15.575078
# Epoch8,Loss:16.930708
# Epoch8,Loss:18.546275
# Epoch8,Loss:19.731494
# Epoch8,Loss:21.220257
# Epoch8,Loss:23.316497
# Epoch8,Loss:24.558044
# Epoch8,Loss:26.439142
# Epoch8,Loss:27.955410
# Epoch8,Loss:29.182819
# Epoch8,Loss:30.634178
# Epoch8,Loss:32.613685
# Epoch8,Loss:33.920884
# Epoch8,Loss:35.862383
# Epoch8,Loss:36.857822
# Epoch8,Loss:38.444109
# Epoch8,Loss:39.968221
# Epoch8,Loss:41.306034
# Epoch8,Loss:42.515916
# Epoch8,Loss:44.274717
# Epoch8,Loss:45.338387
# Epoch8,Loss:46.933545
# Epoch8,Loss:48.310723
# Epoch8,Loss:49.397494
# Epoch8,Loss:51.065123
# Epoch8,Loss:52.294876
# Epoch8,Loss:53.958931
# Epoch8,Loss:54.967791
# Epoch8,Loss:56.035387
# Epoch8,Loss:57.533063
# Epoch8,Loss:59.301854
# Epoch8,Loss:60.259573
# Epoch8,Loss:62.279667
# Epoch8,Loss:62.905267
# Epoch8,Loss:64.339170
# Epoch8,Loss:66.347647
# Epoch8,Loss:68.048160
# Epoch8,Loss:69.858222
# Epoch8,Loss:71.681301
# Epoch8,Loss:72.756376
# Epoch8,Loss:74.374840
# Epoch8,Loss:75.798502
# Epoch8,Loss:77.202876
# Epoch8,Loss:79.258605
# Epoch8,Loss:80.388856
# Epoch8,Loss:81.878522
# Epoch8,Loss:82.768755
# Epoch8,Loss:83.740072
# Epoch8,Loss:84.866533
# Epoch8,Loss:85.886966
# Epoch8,Loss:87.345251
# Epoch8,Loss:88.576953
# Epoch8,Loss:89.982879
# Epoch8,Loss:91.528095
# Epoch8,Loss:93.560545
# Epoch8,Loss:95.177131
# Epoch8,Loss:97.501662
# Epoch8,Loss:98.987086
# Epoch8,Loss:100.317760
# Epoch8,Loss:101.558898
# Epoch8,Loss:102.643850
# Epoch8,Loss:104.319052
# Epoch8,Loss:105.500315
# Epoch8,Loss:106.430589
# Epoch8,Loss:107.957288
# Epoch8,Loss:109.176573
# Epoch8,Loss:110.360144
# Epoch8,Loss:111.813111
# Epoch8,Loss:112.844324
# Epoch8,Loss:114.616951
# Epoch8,Loss:115.872639
# Epoch8,Loss:117.320138
# Epoch8,Loss:118.561491
# Epoch8,Loss:119.724471
# Epoch8,Loss:121.321998
# Epoch8,Loss:123.037876
# Epoch8,Loss:124.193933
# Epoch8,Loss:126.001793
# Epoch8,Loss:128.265031
# Epoch8,Loss:129.577427
# Epoch9,Loss:0.839252
# Epoch9,Loss:1.597441
# Epoch9,Loss:2.422871
# Epoch9,Loss:3.711847
# Epoch9,Loss:4.898087
# Epoch9,Loss:5.621022
# Epoch9,Loss:6.632961
# Epoch9,Loss:7.646043
# Epoch9,Loss:8.525255
# Epoch9,Loss:9.498829
# Epoch9,Loss:10.319938
# Epoch9,Loss:12.089209
# Epoch9,Loss:13.660409
# Epoch9,Loss:15.009595
# Epoch9,Loss:16.157378
# Epoch9,Loss:17.134620
# Epoch9,Loss:17.999679
# Epoch9,Loss:18.762738
# Epoch9,Loss:20.441091
# Epoch9,Loss:21.163703
# Epoch9,Loss:22.378778
# Epoch9,Loss:23.921328
# Epoch9,Loss:25.305912
# Epoch9,Loss:26.180665
# Epoch9,Loss:26.961093
# Epoch9,Loss:28.105702
# Epoch9,Loss:29.141428
# Epoch9,Loss:30.190539
# Epoch9,Loss:31.159592
# Epoch9,Loss:31.918867
# Epoch9,Loss:32.633039
# Epoch9,Loss:33.752310
# Epoch9,Loss:34.968129
# Epoch9,Loss:36.561466
# Epoch9,Loss:37.427139
# Epoch9,Loss:38.648434
# Epoch9,Loss:39.722548
# Epoch9,Loss:41.373508
# Epoch9,Loss:42.624682
# Epoch9,Loss:43.882505
# Epoch9,Loss:45.091309
# Epoch9,Loss:46.248634
# Epoch9,Loss:48.128741
# Epoch9,Loss:49.389272
# Epoch9,Loss:50.829641
# Epoch9,Loss:51.922353
# Epoch9,Loss:52.733191
# Epoch9,Loss:53.830107
# Epoch9,Loss:54.751186
# Epoch9,Loss:56.344491
# Epoch9,Loss:57.245201
# Epoch9,Loss:58.663501
# Epoch9,Loss:59.575094
# Epoch9,Loss:60.629843
# Epoch9,Loss:61.255657
# Epoch9,Loss:62.309797
# Epoch9,Loss:63.418809
# Epoch9,Loss:63.860591
# Epoch9,Loss:64.584045
# Epoch9,Loss:65.301556
# Epoch9,Loss:66.832225
# Epoch9,Loss:68.212830
# Epoch9,Loss:68.962682
# Epoch9,Loss:69.739838
# Epoch9,Loss:70.649270
# Epoch9,Loss:71.791816
# Epoch9,Loss:72.738341
# Epoch9,Loss:74.009253
# Epoch9,Loss:75.802901
# Epoch9,Loss:76.258264
# Epoch9,Loss:77.350824
# Epoch9,Loss:78.268316
# Epoch9,Loss:79.303931
# Epoch9,Loss:79.933588
# Epoch9,Loss:81.779903
# Epoch9,Loss:83.497089
# Epoch9,Loss:84.361249
# Epoch9,Loss:86.091259
# Epoch9,Loss:86.949178
# Epoch9,Loss:87.648712
# Epoch9,Loss:88.746535
# Epoch9,Loss:89.382606
# Epoch9,Loss:90.658566
# Epoch9,Loss:92.270116
# Epoch9,Loss:93.032929
# Epoch9,Loss:94.532007
# Epoch9,Loss:96.445910
# Epoch9,Loss:97.292257
# Epoch9,Loss:98.447507
# Epoch9,Loss:99.248636
# Epoch10,Loss:0.762189
# Epoch10,Loss:1.207400
# Epoch10,Loss:2.449411
# Epoch10,Loss:3.368398
# Epoch10,Loss:3.932058
# Epoch10,Loss:4.836208
# Epoch10,Loss:5.650783
# Epoch10,Loss:6.518481
# Epoch10,Loss:7.510809
# Epoch10,Loss:8.059661
# Epoch10,Loss:8.649169
# Epoch10,Loss:9.473044
# Epoch10,Loss:10.198069
# Epoch10,Loss:10.660250
# Epoch10,Loss:11.165236
# Epoch10,Loss:12.037528
# Epoch10,Loss:12.990414
# Epoch10,Loss:13.853183
# Epoch10,Loss:14.759678
# Epoch10,Loss:15.577005
# Epoch10,Loss:16.131218
# Epoch10,Loss:16.675586
# Epoch10,Loss:17.488728
# Epoch10,Loss:18.220198
# Epoch10,Loss:18.721409
# Epoch10,Loss:19.476063
# Epoch10,Loss:20.416541
# Epoch10,Loss:21.009025
# Epoch10,Loss:21.767928
# Epoch10,Loss:22.671854
# Epoch10,Loss:23.197919
# Epoch10,Loss:24.194179
# Epoch10,Loss:25.072593
# Epoch10,Loss:25.643969
# Epoch10,Loss:26.480032
# Epoch10,Loss:26.917904
# Epoch10,Loss:28.554414
# Epoch10,Loss:30.088003
# Epoch10,Loss:30.914084
# Epoch10,Loss:31.667202
# Epoch10,Loss:32.313434
# Epoch10,Loss:33.739441
# Epoch10,Loss:34.361532
# Epoch10,Loss:35.906503
# Epoch10,Loss:36.422341
# Epoch10,Loss:37.332833
# Epoch10,Loss:38.066480
# Epoch10,Loss:38.679134
# Epoch10,Loss:39.248061
# Epoch10,Loss:40.007043
# Epoch10,Loss:41.551535
# Epoch10,Loss:42.090040
# Epoch10,Loss:42.819873
# Epoch10,Loss:43.987224
# Epoch10,Loss:45.275781
# Epoch10,Loss:46.079365
# Epoch10,Loss:47.207283
# Epoch10,Loss:47.878935
# Epoch10,Loss:49.341299
# Epoch10,Loss:50.292252
# Epoch10,Loss:50.920163
# Epoch10,Loss:51.543558
# Epoch10,Loss:52.106460
# Epoch10,Loss:52.993365
# Epoch10,Loss:54.329498
# Epoch10,Loss:55.013326
# Epoch10,Loss:55.669247
# Epoch10,Loss:56.446298
# Epoch10,Loss:56.889857
# Epoch10,Loss:57.570533
# Epoch10,Loss:58.656949
# Epoch10,Loss:59.278576
# Epoch10,Loss:59.851118
# Epoch10,Loss:60.604478
# Epoch10,Loss:60.962805
# Epoch10,Loss:61.975716
# Epoch10,Loss:62.630368
# Epoch10,Loss:63.836542
# Epoch10,Loss:64.960759
# Epoch10,Loss:65.692299
# Epoch10,Loss:66.284404
# Epoch10,Loss:67.037673
# Epoch10,Loss:68.250631
# Epoch10,Loss:69.372096
# Epoch10,Loss:70.242010
# Epoch10,Loss:70.527385
# Epoch10,Loss:71.759071
# Epoch10,Loss:73.350738
# Epoch10,Loss:73.980499
# Epoch10,Loss:75.636613
# Epoch11,Loss:0.860043
# Epoch11,Loss:1.758640
# Epoch11,Loss:2.927368
# Epoch11,Loss:3.388403
# Epoch11,Loss:3.886331
# Epoch11,Loss:4.272057
# Epoch11,Loss:4.872399
# Epoch11,Loss:5.439626
# Epoch11,Loss:6.453483
# Epoch11,Loss:7.154595
# Epoch11,Loss:7.613068
# Epoch11,Loss:7.953958
# Epoch11,Loss:8.658022
# Epoch11,Loss:9.007254
# Epoch11,Loss:9.844579
# Epoch11,Loss:11.366191
# Epoch11,Loss:11.851912
# Epoch11,Loss:12.623221
# Epoch11,Loss:13.137625
# Epoch11,Loss:13.741629
# Epoch11,Loss:14.168849
# Epoch11,Loss:14.417221
# Epoch11,Loss:15.105930
# Epoch11,Loss:16.155544
# Epoch11,Loss:16.610616
# Epoch11,Loss:17.521820
# Epoch11,Loss:18.111409
# Epoch11,Loss:18.538043
# Epoch11,Loss:18.928808
# Epoch11,Loss:19.330196
# Epoch11,Loss:19.787147
# Epoch11,Loss:20.430171
# Epoch11,Loss:20.988842
# Epoch11,Loss:21.564297
# Epoch11,Loss:22.770365
# Epoch11,Loss:23.261773
# Epoch11,Loss:23.911513
# Epoch11,Loss:24.407148
# Epoch11,Loss:25.050193
# Epoch11,Loss:25.908050
# Epoch11,Loss:26.784604
# Epoch11,Loss:28.239397
# Epoch11,Loss:28.709717
# Epoch11,Loss:29.045873
# Epoch11,Loss:29.645465
# Epoch11,Loss:30.331166
# Epoch11,Loss:30.784137
# Epoch11,Loss:31.229616
# Epoch11,Loss:31.656156
# Epoch11,Loss:32.634267
# Epoch11,Loss:33.081477
# Epoch11,Loss:34.111094
# Epoch11,Loss:34.805277
# Epoch11,Loss:35.002962
# Epoch11,Loss:35.726727
# Epoch11,Loss:36.469536
# Epoch11,Loss:36.838611
# Epoch11,Loss:37.352003
# Epoch11,Loss:37.950258
# Epoch11,Loss:38.688328
# Epoch11,Loss:39.292698
# Epoch11,Loss:40.057246
# Epoch11,Loss:40.698177
# Epoch11,Loss:41.114155
# Epoch11,Loss:41.449687
# Epoch11,Loss:41.870181
# Epoch11,Loss:42.399448
# Epoch11,Loss:43.232048
# Epoch11,Loss:43.971561
# Epoch11,Loss:44.469271
# Epoch11,Loss:46.181130
# Epoch11,Loss:46.579887
# Epoch11,Loss:47.029164
# Epoch11,Loss:47.689654
# Epoch11,Loss:48.362981
# Epoch11,Loss:49.368468
# Epoch11,Loss:50.034696
# Epoch11,Loss:50.487250
# Epoch11,Loss:50.988059
# Epoch11,Loss:51.447553
# Epoch11,Loss:51.873940
# Epoch11,Loss:52.318480
# Epoch11,Loss:52.878056
# Epoch11,Loss:53.517678
# Epoch11,Loss:54.220446
# Epoch11,Loss:55.480878
# Epoch11,Loss:56.497749
# Epoch11,Loss:57.102241
# Epoch11,Loss:57.797414
# Epoch11,Loss:58.280507
# Epoch12,Loss:0.363851
# Epoch12,Loss:0.614993
# Epoch12,Loss:0.894241
# Epoch12,Loss:1.310169
# Epoch12,Loss:1.746002
# Epoch12,Loss:2.079316
# Epoch12,Loss:2.469804
# Epoch12,Loss:2.720483
# Epoch12,Loss:3.199255
# Epoch12,Loss:3.475669
# Epoch12,Loss:3.867774
# Epoch12,Loss:5.110516
# Epoch12,Loss:5.580196
# Epoch12,Loss:5.944448
# Epoch12,Loss:6.397516
# Epoch12,Loss:6.833136
# Epoch12,Loss:7.112115
# Epoch12,Loss:7.551641
# Epoch12,Loss:8.145758
# Epoch12,Loss:8.575936
# Epoch12,Loss:8.888640
# Epoch12,Loss:9.540232
# Epoch12,Loss:9.833335
# Epoch12,Loss:11.207026
# Epoch12,Loss:11.683134
# Epoch12,Loss:12.360691
# Epoch12,Loss:12.784239
# Epoch12,Loss:13.252457
# Epoch12,Loss:13.657540
# Epoch12,Loss:13.973072
# Epoch12,Loss:14.845381
# Epoch12,Loss:15.151120
# Epoch12,Loss:15.803208
# Epoch12,Loss:16.157515
# Epoch12,Loss:16.548540
# Epoch12,Loss:16.905609
# Epoch12,Loss:17.386889
# Epoch12,Loss:17.702489
# Epoch12,Loss:18.257207
# Epoch12,Loss:18.642342
# Epoch12,Loss:19.617271
# Epoch12,Loss:19.990843
# Epoch12,Loss:20.167058
# Epoch12,Loss:20.867889
# Epoch12,Loss:21.185306
# Epoch12,Loss:22.236324
# Epoch12,Loss:22.618859
# Epoch12,Loss:23.353890
# Epoch12,Loss:23.753984
# Epoch12,Loss:23.948046
# Epoch12,Loss:24.253630
# Epoch12,Loss:24.747622
# Epoch12,Loss:25.369386
# Epoch12,Loss:25.698415
# Epoch12,Loss:26.703355
# Epoch12,Loss:27.066296
# Epoch12,Loss:27.599021
# Epoch12,Loss:27.994943
# Epoch12,Loss:28.862570
# Epoch12,Loss:29.572315
# Epoch12,Loss:30.048883
# Epoch12,Loss:30.379277
# Epoch12,Loss:30.711479
# Epoch12,Loss:31.246361
# Epoch12,Loss:31.800800
# Epoch12,Loss:32.134761
# Epoch12,Loss:32.612288
# Epoch12,Loss:33.144014
# Epoch12,Loss:33.695437
# Epoch12,Loss:33.973563
# Epoch12,Loss:34.672993
# Epoch12,Loss:35.043584
# Epoch12,Loss:35.397747
# Epoch12,Loss:36.214360
# Epoch12,Loss:36.787461
# Epoch12,Loss:37.338205
# Epoch12,Loss:37.826985
# Epoch12,Loss:38.174215
# Epoch12,Loss:38.562415
# Epoch12,Loss:40.438329
# Epoch12,Loss:40.915996
# Epoch12,Loss:41.420612
# Epoch12,Loss:41.798547
# Epoch12,Loss:42.152818
# Epoch12,Loss:43.121886
# Epoch12,Loss:43.609137
# Epoch12,Loss:44.170743
# Epoch12,Loss:44.731525
# Epoch12,Loss:45.401946
# Epoch12,Loss:45.715765
# Epoch13,Loss:0.244253
# Epoch13,Loss:0.667624
# Epoch13,Loss:0.865607
# Epoch13,Loss:1.169689
# Epoch13,Loss:1.406695
# Epoch13,Loss:1.774044
# Epoch13,Loss:2.060014
# Epoch13,Loss:2.453587
# Epoch13,Loss:2.725817
# Epoch13,Loss:2.949737
# Epoch13,Loss:3.219842
# Epoch13,Loss:3.543922
# Epoch13,Loss:3.822586
# Epoch13,Loss:4.530189
# Epoch13,Loss:4.807543
# Epoch13,Loss:5.156066
# Epoch13,Loss:5.852561
# Epoch13,Loss:6.573376
# Epoch13,Loss:7.135991
# Epoch13,Loss:7.488372
# Epoch13,Loss:7.980197
# Epoch13,Loss:8.381380
# Epoch13,Loss:8.656678
# Epoch13,Loss:8.950806
# Epoch13,Loss:9.316788
# Epoch13,Loss:9.612813
# Epoch13,Loss:9.840157
# Epoch13,Loss:10.206255
# Epoch13,Loss:10.446455
# Epoch13,Loss:10.709138
# Epoch13,Loss:11.353282
# Epoch13,Loss:11.570193
# Epoch13,Loss:11.961849
# Epoch13,Loss:12.287723
# Epoch13,Loss:12.516545
# Epoch13,Loss:12.838153
# Epoch13,Loss:14.059084
# Epoch13,Loss:14.352317
# Epoch13,Loss:14.821828
# Epoch13,Loss:15.170298
# Epoch13,Loss:15.554430
# Epoch13,Loss:15.890442
# Epoch13,Loss:16.130560
# Epoch13,Loss:16.628364
# Epoch13,Loss:17.136549
# Epoch13,Loss:17.567117
# Epoch13,Loss:18.919413
# Epoch13,Loss:19.160528
# Epoch13,Loss:19.820012
# Epoch13,Loss:20.170254
# Epoch13,Loss:20.557478
# Epoch13,Loss:20.698537
# Epoch13,Loss:21.006998
# Epoch13,Loss:21.298216
# Epoch13,Loss:21.676957
# Epoch13,Loss:22.048994
# Epoch13,Loss:23.685953
# Epoch13,Loss:23.962473
# Epoch13,Loss:24.338651
# Epoch13,Loss:24.707715
# Epoch13,Loss:24.923164
# Epoch13,Loss:25.201628
# Epoch13,Loss:25.695206
# Epoch13,Loss:25.966767
# Epoch13,Loss:26.364801
# Epoch13,Loss:26.640661
# Epoch13,Loss:27.068918
# Epoch13,Loss:27.649968
# Epoch13,Loss:27.808227
# Epoch13,Loss:28.650378
# Epoch13,Loss:28.882642
# Epoch13,Loss:29.147066
# Epoch13,Loss:29.449770
# Epoch13,Loss:29.713974
# Epoch13,Loss:30.193010
# Epoch13,Loss:31.031256
# Epoch13,Loss:31.446828
# Epoch13,Loss:31.815032
# Epoch13,Loss:32.194865
# Epoch13,Loss:32.530709
# Epoch13,Loss:32.798292
# Epoch13,Loss:33.117251
# Epoch13,Loss:33.544232
# Epoch13,Loss:33.944613
# Epoch13,Loss:34.585576
# Epoch13,Loss:34.877141
# Epoch13,Loss:35.161939
# Epoch13,Loss:35.460795
# Epoch13,Loss:36.173857
# Epoch13,Loss:36.475103
# Epoch14,Loss:0.227832
# Epoch14,Loss:0.654482
# Epoch14,Loss:0.976400
# Epoch14,Loss:1.231505
# Epoch14,Loss:1.832315
# Epoch14,Loss:2.224498
# Epoch14,Loss:2.508431
# Epoch14,Loss:2.763085
# Epoch14,Loss:2.957587
# Epoch14,Loss:3.576040
# Epoch14,Loss:3.934592
# Epoch14,Loss:4.190593
# Epoch14,Loss:4.629625
# Epoch14,Loss:4.813191
# Epoch14,Loss:5.069283
# Epoch14,Loss:5.293311
# Epoch14,Loss:5.510519
# Epoch14,Loss:5.772142
# Epoch14,Loss:6.082286
# Epoch14,Loss:6.268404
# Epoch14,Loss:6.532461
# Epoch14,Loss:6.843347
# Epoch14,Loss:7.151556
# Epoch14,Loss:7.377712
# Epoch14,Loss:7.710217
# Epoch14,Loss:7.884647
# Epoch14,Loss:8.092836
# Epoch14,Loss:8.335697
# Epoch14,Loss:8.564482
# Epoch14,Loss:8.793323
# Epoch14,Loss:9.959219
# Epoch14,Loss:10.166197
# Epoch14,Loss:11.328331
# Epoch14,Loss:11.608985
# Epoch14,Loss:11.949535
# Epoch14,Loss:12.171778
# Epoch14,Loss:12.412469
# Epoch14,Loss:12.698787
# Epoch14,Loss:13.020832
# Epoch14,Loss:13.270724
# Epoch14,Loss:13.704958
# Epoch14,Loss:13.955544
# Epoch14,Loss:14.333023
# Epoch14,Loss:14.534380
# Epoch14,Loss:14.880592
# Epoch14,Loss:15.084549
# Epoch14,Loss:15.275549
# Epoch14,Loss:15.671923
# Epoch14,Loss:15.930023
# Epoch14,Loss:16.151324
# Epoch14,Loss:16.422979
# Epoch14,Loss:16.608364
# Epoch14,Loss:16.831767
# Epoch14,Loss:17.159605
# Epoch14,Loss:17.343952
# Epoch14,Loss:17.557498
# Epoch14,Loss:17.850886
# Epoch14,Loss:18.134620
# Epoch14,Loss:18.439140
# Epoch14,Loss:18.556380
# Epoch14,Loss:18.796327
# Epoch14,Loss:19.389631
# Epoch14,Loss:19.711608
# Epoch14,Loss:19.897437
# Epoch14,Loss:20.197157
# Epoch14,Loss:20.440758
# Epoch14,Loss:20.791591
# Epoch14,Loss:21.069753
# Epoch14,Loss:21.571280
# Epoch14,Loss:21.827785
# Epoch14,Loss:22.328873
# Epoch14,Loss:22.810851
# Epoch14,Loss:23.150921
# Epoch14,Loss:23.355713
# Epoch14,Loss:23.586226
# Epoch14,Loss:23.912762
# Epoch14,Loss:24.239794
# Epoch14,Loss:24.457729
# Epoch14,Loss:24.677162
# Epoch14,Loss:26.302454
# Epoch14,Loss:26.468134
# Epoch14,Loss:26.686161
# Epoch14,Loss:27.352786
# Epoch14,Loss:27.547254
# Epoch14,Loss:27.783922
# Epoch14,Loss:28.437013
# Epoch14,Loss:28.762809
# Epoch14,Loss:28.894269
# Epoch14,Loss:29.172704
# Epoch14,Loss:29.718269
# Epoch15,Loss:0.301719
# Epoch15,Loss:0.496791
# Epoch15,Loss:0.646152
# Epoch15,Loss:0.889504
# Epoch15,Loss:1.100700
# Epoch15,Loss:1.352488
# Epoch15,Loss:1.585835
# Epoch15,Loss:2.077387
# Epoch15,Loss:2.257674
# Epoch15,Loss:2.427522
# Epoch15,Loss:3.574649
# Epoch15,Loss:3.995977
# Epoch15,Loss:4.213332
# Epoch15,Loss:4.388550
# Epoch15,Loss:4.556844
# Epoch15,Loss:4.651987
# Epoch15,Loss:4.977538
# Epoch15,Loss:5.184352
# Epoch15,Loss:5.366530
# Epoch15,Loss:5.528860
# Epoch15,Loss:5.678639
# Epoch15,Loss:5.877239
# Epoch15,Loss:6.032321
# Epoch15,Loss:6.386431
# Epoch15,Loss:6.656701
# Epoch15,Loss:6.829801
# Epoch15,Loss:6.988017
# Epoch15,Loss:7.238544
# Epoch15,Loss:7.388652
# Epoch15,Loss:7.607599
# Epoch15,Loss:7.715026
# Epoch15,Loss:8.014159
# Epoch15,Loss:8.443125
# Epoch15,Loss:8.630263
# Epoch15,Loss:8.855064
# Epoch15,Loss:9.036792
# Epoch15,Loss:9.312961
# Epoch15,Loss:9.492658
# Epoch15,Loss:9.753801
# Epoch15,Loss:10.012882
# Epoch15,Loss:10.185232
# Epoch15,Loss:11.375712
# Epoch15,Loss:11.582155
# Epoch15,Loss:11.759123
# Epoch15,Loss:11.966405
# Epoch15,Loss:12.520120
# Epoch15,Loss:12.731562
# Epoch15,Loss:12.992612
# Epoch15,Loss:13.261608
# Epoch15,Loss:13.491806
# Epoch15,Loss:13.717013
# Epoch15,Loss:13.852345
# Epoch15,Loss:14.082581
# Epoch15,Loss:14.306055
# Epoch15,Loss:14.536017
# Epoch15,Loss:14.983568
# Epoch15,Loss:15.148889
# Epoch15,Loss:15.489859
# Epoch15,Loss:15.665048
# Epoch15,Loss:15.866026
# Epoch15,Loss:16.059674
# Epoch15,Loss:17.589640
# Epoch15,Loss:17.765666
# Epoch15,Loss:17.948026
# Epoch15,Loss:18.193096
# Epoch15,Loss:18.429844
# Epoch15,Loss:18.588565
# Epoch15,Loss:18.957127
# Epoch15,Loss:19.111369
# Epoch15,Loss:19.314292
# Epoch15,Loss:19.499599
# Epoch15,Loss:19.795732
# Epoch15,Loss:19.975834
# Epoch15,Loss:20.224467
# Epoch15,Loss:20.508902
# Epoch15,Loss:21.101164
# Epoch15,Loss:21.346565
# Epoch15,Loss:21.788496
# Epoch15,Loss:21.982842
# Epoch15,Loss:22.233627
# Epoch15,Loss:22.613191
# Epoch15,Loss:22.832450
# Epoch15,Loss:23.034348
# Epoch15,Loss:23.242783
# Epoch15,Loss:23.468944
# Epoch15,Loss:23.619572
# Epoch15,Loss:24.144132
# Epoch15,Loss:24.411666
# Epoch15,Loss:24.640077
# Epoch15,Loss:24.925056
# Epoch16,Loss:0.374389
# Epoch16,Loss:0.682338
# Epoch16,Loss:0.866431
# Epoch16,Loss:1.057174
# Epoch16,Loss:1.197959
# Epoch16,Loss:2.126627
# Epoch16,Loss:2.235087
# Epoch16,Loss:2.407049
# Epoch16,Loss:2.549605
# Epoch16,Loss:2.771278
# Epoch16,Loss:3.001055
# Epoch16,Loss:3.132628
# Epoch16,Loss:3.280580
# Epoch16,Loss:3.473638
# Epoch16,Loss:3.674873
# Epoch16,Loss:4.008623
# Epoch16,Loss:4.137478
# Epoch16,Loss:4.267801
# Epoch16,Loss:4.508096
# Epoch16,Loss:4.731007
# Epoch16,Loss:4.899512
# Epoch16,Loss:5.083276
# Epoch16,Loss:5.418039
# Epoch16,Loss:5.599811
# Epoch16,Loss:5.880406
# Epoch16,Loss:6.308439
# Epoch16,Loss:6.455642
# Epoch16,Loss:6.604968
# Epoch16,Loss:6.773124
# Epoch16,Loss:6.959071
# Epoch16,Loss:7.215794
# Epoch16,Loss:8.579866
# Epoch16,Loss:8.771473
# Epoch16,Loss:8.955718
# Epoch16,Loss:9.086774
# Epoch16,Loss:9.248425
# Epoch16,Loss:9.330069
# Epoch16,Loss:9.495699
# Epoch16,Loss:9.936230
# Epoch16,Loss:10.109551
# Epoch16,Loss:10.261568
# Epoch16,Loss:10.427756
# Epoch16,Loss:10.830462
# Epoch16,Loss:11.046364
# Epoch16,Loss:11.206256
# Epoch16,Loss:11.413763
# Epoch16,Loss:11.556009
# Epoch16,Loss:11.965445
# Epoch16,Loss:12.135615
# Epoch16,Loss:12.281369
# Epoch16,Loss:12.522003
# Epoch16,Loss:12.649888
# Epoch16,Loss:12.851244
# Epoch16,Loss:13.062208
# Epoch16,Loss:13.403252
# Epoch16,Loss:13.539973
# Epoch16,Loss:13.686959
# Epoch16,Loss:13.892313
# Epoch16,Loss:14.083477
# Epoch16,Loss:14.206585
# Epoch16,Loss:14.336840
# Epoch16,Loss:14.630402
# Epoch16,Loss:14.832135
# Epoch16,Loss:14.925432
# Epoch16,Loss:15.123712
# Epoch16,Loss:15.352182
# Epoch16,Loss:15.508076
# Epoch16,Loss:15.693239
# Epoch16,Loss:15.841513
# Epoch16,Loss:15.993816
# Epoch16,Loss:16.136036
# Epoch16,Loss:16.304827
# Epoch16,Loss:16.546953
# Epoch16,Loss:16.818630
# Epoch16,Loss:17.057438
# Epoch16,Loss:17.296420
# Epoch16,Loss:17.450708
# Epoch16,Loss:17.648462
# Epoch16,Loss:17.783008
# Epoch16,Loss:17.931144
# Epoch16,Loss:18.085115
# Epoch16,Loss:18.279052
# Epoch16,Loss:18.633027
# Epoch16,Loss:19.982705
# Epoch16,Loss:20.132500
# Epoch16,Loss:20.357046
# Epoch16,Loss:20.540139
# Epoch16,Loss:20.713395
# Epoch16,Loss:20.871995
# Epoch16,Loss:21.102362
# Epoch17,Loss:0.142518
# Epoch17,Loss:0.269983
# Epoch17,Loss:0.400697
# Epoch17,Loss:0.521227
# Epoch17,Loss:0.681205
# Epoch17,Loss:0.750857
# Epoch17,Loss:0.865595
# Epoch17,Loss:1.186852
# Epoch17,Loss:1.383848
# Epoch17,Loss:1.529973
# Epoch17,Loss:1.655491
# Epoch17,Loss:1.768980
# Epoch17,Loss:1.967105
# Epoch17,Loss:2.232918
# Epoch17,Loss:2.401948
# Epoch17,Loss:2.529083
# Epoch17,Loss:2.662533
# Epoch17,Loss:2.807488
# Epoch17,Loss:2.962649
# Epoch17,Loss:3.089601
# Epoch17,Loss:3.263698
# Epoch17,Loss:3.385629
# Epoch17,Loss:3.521332
# Epoch17,Loss:3.681588
# Epoch17,Loss:3.863545
# Epoch17,Loss:4.233459
# Epoch17,Loss:4.343710
# Epoch17,Loss:4.457543
# Epoch17,Loss:4.604573
# Epoch17,Loss:4.773611
# Epoch17,Loss:4.954832
# Epoch17,Loss:5.113500
# Epoch17,Loss:5.247907
# Epoch17,Loss:5.563823
# Epoch17,Loss:5.808853
# Epoch17,Loss:5.981388
# Epoch17,Loss:6.149817
# Epoch17,Loss:6.334696
# Epoch17,Loss:6.453492
# Epoch17,Loss:6.696411
# Epoch17,Loss:6.893319
# Epoch17,Loss:7.008038
# Epoch17,Loss:7.166202
# Epoch17,Loss:7.312513
# Epoch17,Loss:7.464708
# Epoch17,Loss:7.653340
# Epoch17,Loss:7.762920
# Epoch17,Loss:7.841232
# Epoch17,Loss:8.048838
# Epoch17,Loss:8.216283
# Epoch17,Loss:8.367825
# Epoch17,Loss:8.522686
# Epoch17,Loss:8.665521
# Epoch17,Loss:8.953838
# Epoch17,Loss:9.110598
# Epoch17,Loss:9.306942
# Epoch17,Loss:9.467117
# Epoch17,Loss:9.658718
# Epoch17,Loss:10.786411
# Epoch17,Loss:10.983416
# Epoch17,Loss:11.109378
# Epoch17,Loss:11.385120
# Epoch17,Loss:11.492726
# Epoch17,Loss:11.707416
# Epoch17,Loss:11.828824
# Epoch17,Loss:11.958765
# Epoch17,Loss:12.973839
# Epoch17,Loss:13.069151
# Epoch17,Loss:13.193973
# Epoch17,Loss:13.347884
# Epoch17,Loss:13.506529
# Epoch17,Loss:13.634833
# Epoch17,Loss:13.811533
# Epoch17,Loss:14.201468
# Epoch17,Loss:14.327642
# Epoch17,Loss:14.489322
# Epoch17,Loss:15.620304
# Epoch17,Loss:15.733157
# Epoch17,Loss:15.877400
# Epoch17,Loss:16.002059
# Epoch17,Loss:16.162651
# Epoch17,Loss:16.295506
# Epoch17,Loss:16.560020
# Epoch17,Loss:16.743955
# Epoch17,Loss:16.875050
# Epoch17,Loss:17.207957
# Epoch17,Loss:17.416956
# Epoch17,Loss:17.658805
# Epoch17,Loss:17.773637
# Epoch17,Loss:17.883649
# Epoch18,Loss:0.805221
# Epoch18,Loss:0.936075
# Epoch18,Loss:1.091502
# Epoch18,Loss:1.219772
# Epoch18,Loss:1.363889
# Epoch18,Loss:1.601646
# Epoch18,Loss:1.673118
# Epoch18,Loss:1.787498
# Epoch18,Loss:2.072110
# Epoch18,Loss:2.209968
# Epoch18,Loss:2.269623
# Epoch18,Loss:2.402752
# Epoch18,Loss:2.499698
# Epoch18,Loss:2.736958
# Epoch18,Loss:2.931194
# Epoch18,Loss:3.038260
# Epoch18,Loss:3.180635
# Epoch18,Loss:3.301994
# Epoch18,Loss:3.410809
# Epoch18,Loss:3.517986
# Epoch18,Loss:3.695022
# Epoch18,Loss:3.982294
# Epoch18,Loss:4.078782
# Epoch18,Loss:4.232975
# Epoch18,Loss:4.360529
# Epoch18,Loss:4.485164
# Epoch18,Loss:4.653808
# Epoch18,Loss:4.786719
# Epoch18,Loss:4.953603
# Epoch18,Loss:5.084788
# Epoch18,Loss:5.190309
# Epoch18,Loss:5.336493
# Epoch18,Loss:5.460810
# Epoch18,Loss:5.641367
# Epoch18,Loss:5.741683
# Epoch18,Loss:5.856622
# Epoch18,Loss:6.021951
# Epoch18,Loss:6.149477
# Epoch18,Loss:6.289249
# Epoch18,Loss:7.226922
# Epoch18,Loss:7.440893
# Epoch18,Loss:7.522791
# Epoch18,Loss:7.672585
# Epoch18,Loss:7.792832
# Epoch18,Loss:7.892678
# Epoch18,Loss:7.992598
# Epoch18,Loss:8.105060
# Epoch18,Loss:8.263415
# Epoch18,Loss:8.406028
# Epoch18,Loss:8.540771
# Epoch18,Loss:8.697631
# Epoch18,Loss:8.824123
# Epoch18,Loss:8.962448
# Epoch18,Loss:9.085521
# Epoch18,Loss:9.194595
# Epoch18,Loss:9.309331
# Epoch18,Loss:9.418738
# Epoch18,Loss:9.541427
# Epoch18,Loss:9.633119
# Epoch18,Loss:9.736003
# Epoch18,Loss:9.841312
# Epoch18,Loss:10.004131
# Epoch18,Loss:10.128343
# Epoch18,Loss:10.338280
# Epoch18,Loss:10.435463
# Epoch18,Loss:10.554261
# Epoch18,Loss:10.704532
# Epoch18,Loss:10.930499
# Epoch18,Loss:11.036078
# Epoch18,Loss:11.198179
# Epoch18,Loss:11.340192
# Epoch18,Loss:11.468569
# Epoch18,Loss:11.586892
# Epoch18,Loss:11.746449
# Epoch18,Loss:11.913100
# Epoch18,Loss:12.215642
# Epoch18,Loss:12.449395
# Epoch18,Loss:12.554736
# Epoch18,Loss:12.689535
# Epoch18,Loss:12.931469
# Epoch18,Loss:13.207196
# Epoch18,Loss:13.304607
# Epoch18,Loss:13.419715
# Epoch18,Loss:13.569388
# Epoch18,Loss:13.692179
# Epoch18,Loss:15.008693
# Epoch18,Loss:15.118786
# Epoch18,Loss:15.205943
# Epoch18,Loss:15.300116
# Epoch18,Loss:15.470046
# Epoch19,Loss:0.089966
# Epoch19,Loss:0.173065
# Epoch19,Loss:0.408064
# Epoch19,Loss:0.540836
# Epoch19,Loss:0.632946
# Epoch19,Loss:0.730284
# Epoch19,Loss:0.835562
# Epoch19,Loss:0.988951
# Epoch19,Loss:1.104942
# Epoch19,Loss:1.184342
# Epoch19,Loss:1.297775
# Epoch19,Loss:1.519270
# Epoch19,Loss:1.696195
# Epoch19,Loss:1.827811
# Epoch19,Loss:1.950796
# Epoch19,Loss:2.067307
# Epoch19,Loss:2.189889
# Epoch19,Loss:2.294215
# Epoch19,Loss:2.364743
# Epoch19,Loss:2.463682
# Epoch19,Loss:2.544429
# Epoch19,Loss:2.729431
# Epoch19,Loss:2.867369
# Epoch19,Loss:2.964730
# Epoch19,Loss:3.073538
# Epoch19,Loss:3.151770
# Epoch19,Loss:3.205729
# Epoch19,Loss:3.316527
# Epoch19,Loss:3.413495
# Epoch19,Loss:3.589499
# Epoch19,Loss:3.769420
# Epoch19,Loss:3.870614
# Epoch19,Loss:3.976901
# Epoch19,Loss:4.069452
# Epoch19,Loss:4.195440
# Epoch19,Loss:4.295402
# Epoch19,Loss:4.917519
# Epoch19,Loss:5.059446
# Epoch19,Loss:5.155215
# Epoch19,Loss:5.417143
# Epoch19,Loss:5.522794
# Epoch19,Loss:5.660245
# Epoch19,Loss:5.755688
# Epoch19,Loss:5.875037
# Epoch19,Loss:5.960826
# Epoch19,Loss:6.096334
# Epoch19,Loss:6.193882
# Epoch19,Loss:6.351082
# Epoch19,Loss:6.431409
# Epoch19,Loss:6.537295
# Epoch19,Loss:7.459268
# Epoch19,Loss:7.595038
# Epoch19,Loss:7.687693
# Epoch19,Loss:7.774717
# Epoch19,Loss:8.051914
# Epoch19,Loss:8.152192
# Epoch19,Loss:8.252420
# Epoch19,Loss:8.367830
# Epoch19,Loss:8.503565
# Epoch19,Loss:8.644212
# Epoch19,Loss:8.732143
# Epoch19,Loss:8.860937
# Epoch19,Loss:8.954570
# Epoch19,Loss:9.053944
# Epoch19,Loss:9.184037
# Epoch19,Loss:9.296952
# Epoch19,Loss:9.387046
# Epoch19,Loss:9.480005
# Epoch19,Loss:9.568625
# Epoch19,Loss:9.684735
# Epoch19,Loss:9.798563
# Epoch19,Loss:9.888580
# Epoch19,Loss:10.009850
# Epoch19,Loss:11.077662
# Epoch19,Loss:11.224021
# Epoch19,Loss:11.508082
# Epoch19,Loss:11.622352
# Epoch19,Loss:11.804073
# Epoch19,Loss:11.921540
# Epoch19,Loss:12.091706
# Epoch19,Loss:12.153170
# Epoch19,Loss:12.299081
# Epoch19,Loss:12.434902
# Epoch19,Loss:12.543599
# Epoch19,Loss:12.666591
# Epoch19,Loss:12.797907
# Epoch19,Loss:12.906767
# Epoch19,Loss:13.026781
# Epoch19,Loss:13.184075
# Epoch19,Loss:13.369176
# Epoch20,Loss:0.147278
# Epoch20,Loss:0.227895
# Epoch20,Loss:0.303697
# Epoch20,Loss:0.401359
# Epoch20,Loss:0.477584
# Epoch20,Loss:0.557940
# Epoch20,Loss:0.660060
# Epoch20,Loss:0.755231
# Epoch20,Loss:0.969055
# Epoch20,Loss:1.044960
# Epoch20,Loss:1.139833
# Epoch20,Loss:1.268326
# Epoch20,Loss:1.370270
# Epoch20,Loss:1.445501
# Epoch20,Loss:1.540340
# Epoch20,Loss:1.616094
# Epoch20,Loss:2.270385
# Epoch20,Loss:2.362629
# Epoch20,Loss:2.468689
# Epoch20,Loss:2.544193
# Epoch20,Loss:2.630191
# Epoch20,Loss:2.759934
# Epoch20,Loss:2.855647
# Epoch20,Loss:2.971326
# Epoch20,Loss:3.054224
# Epoch20,Loss:3.167366
# Epoch20,Loss:3.228778
# Epoch20,Loss:3.339302
# Epoch20,Loss:3.415445
# Epoch20,Loss:3.534796
# Epoch20,Loss:3.590573
# Epoch20,Loss:3.701175
# Epoch20,Loss:3.800343
# Epoch20,Loss:3.900873
# Epoch20,Loss:4.033720
# Epoch20,Loss:4.136978
# Epoch20,Loss:4.345341
# Epoch20,Loss:4.470476
# Epoch20,Loss:4.586911
# Epoch20,Loss:4.798272
# Epoch20,Loss:5.423859
# Epoch20,Loss:5.521507
# Epoch20,Loss:5.631210
# Epoch20,Loss:5.797491
# Epoch20,Loss:5.950074
# Epoch20,Loss:6.053353
# Epoch20,Loss:6.141450
# Epoch20,Loss:6.228740
# Epoch20,Loss:6.309048
# Epoch20,Loss:6.395861
# Epoch20,Loss:6.533238
# Epoch20,Loss:6.705687
# Epoch20,Loss:6.832125
# Epoch20,Loss:6.914810
# Epoch20,Loss:7.004469
# Epoch20,Loss:7.167642
# Epoch20,Loss:7.324235
# Epoch20,Loss:7.538045
# Epoch20,Loss:7.633603
# Epoch20,Loss:7.720005
# Epoch20,Loss:7.844487
# Epoch20,Loss:7.929874
# Epoch20,Loss:8.032018
# Epoch20,Loss:8.117071
# Epoch20,Loss:8.213460
# Epoch20,Loss:8.310141
# Epoch20,Loss:8.382191
# Epoch20,Loss:8.506347
# Epoch20,Loss:8.636184
# Epoch20,Loss:8.761246
# Epoch20,Loss:8.849062
# Epoch20,Loss:8.946436
# Epoch20,Loss:9.011244
# Epoch20,Loss:9.096488
# Epoch20,Loss:9.203799
# Epoch20,Loss:9.284987
# Epoch20,Loss:9.423086
# Epoch20,Loss:9.496624
# Epoch20,Loss:9.578183
# Epoch20,Loss:9.672148
# Epoch20,Loss:10.642868
# Epoch20,Loss:10.866856
# Epoch20,Loss:10.941264
# Epoch20,Loss:11.051043
# Epoch20,Loss:11.153748
# Epoch20,Loss:11.267721
# Epoch20,Loss:11.383215
# Epoch20,Loss:11.499226
# Epoch20,Loss:11.545306
# Epoch20,Loss:11.616394

# %%
def predict(model,question,threshold=0.5):
  #convert question to numbers
  numerical_question=text_to_indices(question,vocab)

  #tensor
  question_tensor=torch.tensor(numerical_question).unsqueeze(0)

  #send to model
  output=model(question_tensor)

  #coert to logits to probs
  probs=torch.nn.functional.softmax(output,dim=1)

  #findindex of max prob
  value,index=torch.max(probs,dim=1)

  if value < threshold:
    print("i dont know")

  print(list(vocab.keys())[index])

# %%
predict(model,"What is the freezing point of water in Fahrenheit?")
# Out:
# 32

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-aa378cfc3602> in <cell line: 0>()
# ----> 1 print(list(vocab.keys())[index])
#
# NameError: name 'index' is not defined
